# %%
import meshcat
import meshcat.geometry as g
import numpy as np
import jax
import jax.numpy as jnp
from jaxlie import SE3, SO3

from sdf_world.sdf_world import *
from sdf_world.robots import *

# %%
from torch.utils.tensorboard import SummaryWriter

# %%
from network import *
from loss import *
from train import *

# %%
world = SDFWorld()
panda_model = RobotModel(PANDA_URDF, PANDA_PACKAGE)
# Out:
# You can open the visualizer by visiting the following URL:
# http://127.0.0.1:7003/static/
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts
# concatenating texture: may result in visual artifacts

# %%
world.show_in_jupyter()
# Out:
#             <div style="height: 400px; width: 100%; overflow-x: auto; overflow-y: hidden; resize: both">
#             <iframe src="http://127.0.0.1:7003/static/" style="width: 100%; height: 100%; border: none"></iframe>
#             </div>

# %%
panda = Robot(world.vis, "panda", panda_model)

# %%
def batch_fk(qs):
    gripper_joints = jnp.full((qs.shape[0], 2), 0.04)
    qs = jnp.hstack([qs, gripper_joints])
    return jax.vmap(panda_model.fk_fn)(qs)

# %%
from jax import random
hp = Hyperparam()
hp.dims = [10, 10, 10, 1]
hp.lr = 0.001
hp.batch_size = 128

model = get_mlp(hp)
key1, key2 = random.split(random.PRNGKey(0))
x = random.normal(key1, (hp.dims[0],))
params = model.init(key2, x)
tx = optax.adam(learning_rate=hp.lr)
state = TrainState.create(apply_fn=model.apply, params=params, tx=tx)

# %%
def get_ee_and_elbowxyz(q):
    gripper_joints = jnp.full((2), 0.04)
    qnew = jnp.hstack([q, gripper_joints])
    posevecs = panda_model.fk_fn(qnew)
    elbow_xyz = posevecs[4][-3:]
    ee_pose = posevecs[-1]
    return jnp.hstack([ee_pose, elbow_xyz])
@jax.jit
def get_batch_samples(qs):
    x_succ = jax.vmap(get_ee_and_elbowxyz)(qs)
    random_xyz = np.random.uniform([-1,-1,0.5],[1,1,1.5],size=(qs.shape[0],3))
    x_fail = x_succ.at[:,-3:].set(random_xyz)
    return x_succ, x_fail

def loss(state, params, x_succ, x_fail):
    logits_succ = state.apply_fn(params, x_succ).flatten()
    loss_succ = optax.sigmoid_binary_cross_entropy(
        logits_succ, jnp.ones_like(logits_succ)).mean()
    logits_fail = state.apply_fn(params, x_fail).flatten()
    loss_fail = optax.sigmoid_binary_cross_entropy(
        logits_fail, jnp.zeros_like(logits_fail)).mean()
    return loss_succ + loss_fail
grad_fn = jax.value_and_grad(loss, argnums=1)
@jax.jit
def training_step(state, x_succ, x_fail):
    loss, grads = grad_fn(state, state.params, x_succ, x_fail)
    state = state.apply_gradients(grads=grads)
    return state, loss

# %%
for epoch in range(1000):
    qs = np.random.uniform(panda_model.lb[:7], panda_model.ub[:7], size=(10000,7))
    x_succ, x_fail = get_batch_samples(qs)
    state, loss = training_step(state, x_succ, x_fail)
    print(f"loss:{loss}")
# Out:
# loss:0.49723729491233826
# loss:0.4928097426891327
# loss:0.4915361702442169
# loss:0.48887109756469727
# loss:0.4832706153392792
# loss:0.4755799472332001
# loss:0.4750351905822754
# loss:0.4740275740623474
# loss:0.4671279788017273
# loss:0.46403226256370544
# loss:0.4613837003707886
# loss:0.4561329185962677
# loss:0.4579515755176544
# loss:0.449409157037735
# loss:0.44644567370414734
# loss:0.44546815752983093
# loss:0.44219475984573364
# loss:0.43885916471481323
# loss:0.4329032599925995
# loss:0.43118128180503845
# loss:0.4298625588417053
# loss:0.42395535111427307
# loss:0.4227527678012848
# loss:0.4192536175251007
# loss:0.4170992970466614
# loss:0.4127121567726135
# loss:0.4085482060909271
# loss:0.40597057342529297
# loss:0.4039827883243561
# loss:0.39887911081314087
# loss:0.396720290184021
# loss:0.39366087317466736
# loss:0.39136964082717896
# loss:0.38900500535964966
# loss:0.3871444761753082
# loss:0.3815840184688568
# loss:0.38070148229599
# loss:0.38116952776908875
# loss:0.3762173056602478
# loss:0.3736759126186371
# loss:0.3703068494796753
# loss:0.368512362241745
# loss:0.36274439096450806
# loss:0.36292943358421326
# loss:0.360133558511734
# loss:0.35601237416267395
# loss:0.3505455255508423
# loss:0.35141894221305847
# loss:0.34808865189552307
# loss:0.347723126411438
# loss:0.3437187373638153
# loss:0.3383866548538208
# loss:0.3385459780693054
# loss:0.3377951681613922
# loss:0.3362690210342407
# loss:0.3324093520641327
# loss:0.33150753378868103
# loss:0.3257690966129303
# loss:0.32364600896835327
# loss:0.32322993874549866
# loss:0.32298147678375244
# loss:0.3199494481086731
# loss:0.3159942030906677
# loss:0.3145659267902374
# loss:0.31305986642837524
# loss:0.3134274482727051
# loss:0.3105393350124359
# loss:0.30595144629478455
# loss:0.30513060092926025
# loss:0.3040997087955475
# loss:0.30069810152053833
# loss:0.2975706458091736
# loss:0.2977706491947174
# loss:0.2937915027141571
# loss:0.293302446603775
# loss:0.29550379514694214
# loss:0.2908303141593933
# loss:0.2903781831264496
# loss:0.2862837314605713
# loss:0.28516456484794617
# loss:0.282264769077301
# loss:0.28003576397895813
# loss:0.2788691818714142
# loss:0.276154100894928
# loss:0.2765817940235138
# loss:0.2754404842853546
# loss:0.27143704891204834
# loss:0.2734089195728302
# loss:0.26655444502830505
# loss:0.26768389344215393
# loss:0.2649495601654053
# loss:0.2642659544944763
# loss:0.2617458999156952
# loss:0.2596774995326996
# loss:0.2568977475166321
# loss:0.2581343650817871
# loss:0.25533586740493774
# loss:0.2531050443649292
# loss:0.25676724314689636
# loss:0.2532288432121277
# loss:0.25231167674064636
# loss:0.2511204779148102
# loss:0.25056180357933044
# loss:0.24421268701553345
# loss:0.24580606818199158
# loss:0.24678568542003632
# loss:0.24297912418842316
# loss:0.2425788938999176
# loss:0.2385079562664032
# loss:0.23871168494224548
# loss:0.23639589548110962
# loss:0.23617978394031525
# loss:0.23362237215042114
# loss:0.2341342270374298
# loss:0.23188112676143646
# loss:0.23143772780895233
# loss:0.23134258389472961
# loss:0.22832579910755157
# loss:0.22655393183231354
# loss:0.2271103709936142
# loss:0.22763442993164062
# loss:0.22508013248443604
# loss:0.22242404520511627
# loss:0.2184167355298996
# loss:0.221723273396492
# loss:0.22117288410663605
# loss:0.2199116051197052
# loss:0.21781335771083832
# loss:0.22067320346832275
# loss:0.21516385674476624
# loss:0.21627236902713776
# loss:0.21247051656246185
# loss:0.21163970232009888
# loss:0.21245668828487396
# loss:0.20872870087623596
# loss:0.21024367213249207
# loss:0.2087564617395401
# loss:0.2057633250951767
# loss:0.20702125132083893
# loss:0.2053319662809372
# loss:0.2060355544090271
# loss:0.20625680685043335
# loss:0.2019374668598175
# loss:0.20250757038593292
# loss:0.1986398696899414
# loss:0.2011244297027588
# loss:0.20070718228816986
# loss:0.1973782628774643
# loss:0.1969808042049408
# loss:0.19811053574085236
# loss:0.19706566631793976
# loss:0.19507940113544464
# loss:0.1945192664861679
# loss:0.1923755407333374
# loss:0.1929030567407608
# loss:0.19433452188968658
# loss:0.18923360109329224
# loss:0.19156891107559204
# loss:0.18730361759662628
# loss:0.18930014967918396
# loss:0.18767490983009338
# loss:0.18716450035572052
# loss:0.18569956719875336
# loss:0.18515732884407043
# loss:0.1845596432685852
# loss:0.18473565578460693
# loss:0.1825474053621292
# loss:0.18306267261505127
# loss:0.18208099901676178
# loss:0.18028220534324646
# loss:0.18199384212493896
# loss:0.18059252202510834
# loss:0.17903710901737213
# loss:0.1790524572134018
# loss:0.1797049343585968
# loss:0.1785009503364563
# loss:0.1774962842464447
# loss:0.18002185225486755
# loss:0.17624297738075256
# loss:0.17497700452804565
# loss:0.17378364503383636
# loss:0.1742161065340042
# loss:0.1761646419763565
# loss:0.17433762550354004
# loss:0.17327581346035004
# loss:0.16898654401302338
# loss:0.1712072789669037
# loss:0.16903811693191528
# loss:0.16891498863697052
# loss:0.17074301838874817
# loss:0.16744562983512878
# loss:0.1672266572713852
# loss:0.1659996509552002
# loss:0.16540567576885223
# loss:0.16680148243904114
# loss:0.16441985964775085
# loss:0.16274715960025787
# loss:0.1622542142868042
# loss:0.1627677083015442
# loss:0.16191032528877258
# loss:0.1626352220773697
# loss:0.16151989996433258
# loss:0.16333331167697906
# loss:0.1611519753932953
# loss:0.1612558662891388
# loss:0.1589597761631012
# loss:0.16038459539413452
# loss:0.15832965075969696
# loss:0.15763168036937714
# loss:0.157611683011055
# loss:0.15732628107070923
# loss:0.1587742269039154
# loss:0.1567673236131668
# loss:0.15636450052261353
# loss:0.15649358928203583
# loss:0.15571537613868713
# loss:0.15558941662311554
# loss:0.15184557437896729
# loss:0.1554172933101654
# loss:0.15430477261543274
# loss:0.15387047827243805
# loss:0.15265101194381714
# loss:0.15205565094947815
# loss:0.15091633796691895
# loss:0.15142005681991577
# loss:0.14882978796958923
# loss:0.15093955397605896
# loss:0.15019868314266205
# loss:0.15024393796920776
# loss:0.1459680050611496
# loss:0.15116837620735168
# loss:0.149349644780159
# loss:0.14674857258796692
# loss:0.14819501340389252
# loss:0.14724647998809814
# loss:0.14473339915275574
# loss:0.14694884419441223
# loss:0.1436832845211029
# loss:0.1461087465286255
# loss:0.1459386646747589
# loss:0.1463834047317505
# loss:0.1437453329563141
# loss:0.14386150240898132
# loss:0.14575587213039398
# loss:0.1424865871667862
# loss:0.14323405921459198
# loss:0.143116757273674
# loss:0.1408981829881668
# loss:0.13879697024822235
# loss:0.14199315011501312
# loss:0.14370331168174744
# loss:0.13920266926288605
# loss:0.1391473263502121
# loss:0.13907024264335632
# loss:0.13993997871875763
# loss:0.1400986909866333
# loss:0.1381290853023529
# loss:0.13771763443946838
# loss:0.1366710215806961
# loss:0.13653893768787384
# loss:0.1410742849111557
# loss:0.13480164110660553
# loss:0.13688874244689941
# loss:0.1362583041191101
# loss:0.13790340721607208
# loss:0.13746219873428345
# loss:0.13871647417545319
# loss:0.1352386176586151
# loss:0.13573916256427765
# loss:0.13370728492736816
# loss:0.13220413029193878
# loss:0.1341901570558548
# loss:0.13467873632907867
# loss:0.13582521677017212
# loss:0.13014797866344452
# loss:0.1297699213027954
# loss:0.13237349689006805
# loss:0.1323436200618744
# loss:0.13243629038333893
# loss:0.13023477792739868
# loss:0.13339455425739288
# loss:0.13082380592823029
# loss:0.13172337412834167
# loss:0.1305951625108719
# loss:0.1296897828578949
# loss:0.1307031214237213
# loss:0.1281992346048355
# loss:0.1282205879688263
# loss:0.12877745926380157
# loss:0.12831689417362213
# loss:0.12798796594142914
# loss:0.1323414146900177
# loss:0.1272435039281845
# loss:0.12627215683460236
# loss:0.12637238204479218
# loss:0.1258663833141327
# loss:0.12518182396888733
# loss:0.12559320032596588
# loss:0.12407837063074112
# loss:0.12719246745109558
# loss:0.12496697157621384
# loss:0.12385018169879913
# loss:0.12407787889242172
# loss:0.1231943890452385
# loss:0.12322982400655746
# loss:0.12346011400222778
# loss:0.12372252345085144
# loss:0.12355872243642807
# loss:0.12385798990726471
# loss:0.1240614503622055
# loss:0.12356103211641312
# loss:0.12234991788864136
# loss:0.11986028403043747
# loss:0.12268703430891037
# loss:0.12038155645132065
# loss:0.1188405379652977
# loss:0.1236475482583046
# loss:0.12147703766822815
# loss:0.11989201605319977
# loss:0.12277854979038239
# loss:0.12257866561412811
# loss:0.1230916678905487
# loss:0.1197335496544838
# loss:0.11815278977155685
# loss:0.12212619185447693
# loss:0.11991766095161438
# loss:0.11841171979904175
# loss:0.11827416718006134
# loss:0.11815539747476578
# loss:0.11784086376428604
# loss:0.12107564508914948
# loss:0.11861809343099594
# loss:0.11716347932815552
# loss:0.11733979731798172
# loss:0.11862929165363312
# loss:0.1185578778386116
# loss:0.11850760877132416
# loss:0.11747634410858154
# loss:0.1152825728058815
# loss:0.11698690056800842
# loss:0.11467629671096802
# loss:0.11554092168807983
# loss:0.11500243097543716
# loss:0.11382271349430084
# loss:0.11345779150724411
# loss:0.11515594273805618
# loss:0.1144489273428917
# loss:0.11318008601665497
# loss:0.11519978195428848
# loss:0.11537255346775055
# loss:0.11535347253084183
# loss:0.11578917503356934
# loss:0.11448156088590622
# loss:0.1145501509308815
# loss:0.11346599459648132
# loss:0.11459255963563919
# loss:0.11263491958379745
# loss:0.11199522763490677
# loss:0.1136314794421196
# loss:0.11336539685726166
# loss:0.11085183173418045
# loss:0.11166539043188095
# loss:0.11130832135677338
# loss:0.11051925271749496
# loss:0.11436331272125244
# loss:0.11275181919336319
# loss:0.11274264752864838
# loss:0.10946681350469589
# loss:0.11073687672615051
# loss:0.1110035702586174
# loss:0.11062514036893845
# loss:0.11048340052366257
# loss:0.11108936369419098
# loss:0.11028598248958588
# loss:0.10898718982934952
# loss:0.10994593799114227
# loss:0.10964687168598175
# loss:0.11037109792232513
# loss:0.10707072168588638
# loss:0.10697735846042633
# loss:0.1102316677570343
# loss:0.11116643995046616
# loss:0.10807330906391144
# loss:0.11007902026176453
# loss:0.10764147341251373
# loss:0.10775585472583771
# loss:0.10819873958826065
# loss:0.10822715610265732
# loss:0.10978831350803375
# loss:0.10678645223379135
# loss:0.10860560834407806
# loss:0.10696230828762054
# loss:0.10753165930509567
# loss:0.10573744773864746
# loss:0.10739444941282272
# loss:0.10349347442388535
# loss:0.10499664396047592
# loss:0.10771870613098145
# loss:0.1079811155796051
# loss:0.10359904170036316
# loss:0.10542371869087219
# loss:0.10658831894397736
# loss:0.10444433987140656
# loss:0.10646707564592361
# loss:0.10537070780992508
# loss:0.10346507281064987
# loss:0.10493959486484528
# loss:0.10351763665676117
# loss:0.10473862290382385
# loss:0.10581503063440323
# loss:0.10513827949762344
# loss:0.10346168279647827
# loss:0.10310694575309753
# loss:0.10433287918567657
# loss:0.10737260431051254
# loss:0.10455421358346939
# loss:0.10466204583644867
# loss:0.10395924746990204
# loss:0.10376089811325073
# loss:0.10161946713924408
# loss:0.10191624611616135
# loss:0.10345286875963211
# loss:0.10360755771398544
# loss:0.10242199897766113
# loss:0.10145705938339233
# loss:0.10359980165958405
# loss:0.10207917541265488
# loss:0.10298023372888565
# loss:0.10290180891752243
# loss:0.10026580095291138
# loss:0.10171118378639221
# loss:0.10129877179861069
# loss:0.10460233688354492
# loss:0.10051126778125763
# loss:0.10176761448383331
# loss:0.10316326469182968
# loss:0.10197706520557404
# loss:0.10089582204818726
# loss:0.09904031455516815
# loss:0.0988805964589119
# loss:0.10191135108470917
# loss:0.10046674311161041
# loss:0.09982803463935852
# loss:0.10102283209562302
# loss:0.10028081387281418
# loss:0.10036982595920563
# loss:0.10045839101076126
# loss:0.09760788828134537
# loss:0.10006935149431229
# loss:0.10012210160493851
# loss:0.10082923620939255
# loss:0.09791228175163269
# loss:0.09864270687103271
# loss:0.0992175042629242
# loss:0.09703327715396881
# loss:0.10045912116765976
# loss:0.10142862051725388
# loss:0.10141827911138535
# loss:0.0961061641573906
# loss:0.0990842804312706
# loss:0.09824251383543015
# loss:0.09770099818706512
# loss:0.09887385368347168
# loss:0.09870492666959763
# loss:0.09930351376533508
# loss:0.09706282615661621
# loss:0.09845282137393951
# loss:0.09503456205129623
# loss:0.0974375382065773
# loss:0.09851983934640884
# loss:0.09818653017282486
# loss:0.09554992616176605
# loss:0.09655039757490158
# loss:0.09739232808351517
# loss:0.09709310531616211
# loss:0.09776755422353745
# loss:0.09957928955554962
# loss:0.09767338633537292
# loss:0.09727510064840317
# loss:0.09694444388151169
# loss:0.09632305055856705
# loss:0.09568803757429123
# loss:0.0945446789264679
# loss:0.097295843064785
# loss:0.09435024112462997
# loss:0.09370819479227066
# loss:0.09377649426460266
# loss:0.09549105912446976
# loss:0.09460002183914185
# loss:0.09515160322189331
# loss:0.09679313749074936
# loss:0.09515715390443802
# loss:0.09501796960830688
# loss:0.09483495354652405
# loss:0.0947125107049942
# loss:0.09685265272855759
# loss:0.09277652949094772
# loss:0.09323454648256302
# loss:0.09529241174459457
# loss:0.0940222516655922
# loss:0.09499093890190125
# loss:0.09340541064739227
# loss:0.09393445402383804
# loss:0.0925893485546112
# loss:0.09170487523078918
# loss:0.09450142085552216
# loss:0.09113683551549911
# loss:0.09469906240701675
# loss:0.0937238484621048
# loss:0.09404605627059937
# loss:0.09408742189407349
# loss:0.09243381768465042
# loss:0.09262005239725113
# loss:0.09541051834821701
# loss:0.09322477132081985
# loss:0.09414143115282059
# loss:0.09244074672460556
# loss:0.09187673777341843
# loss:0.09193514287471771
# loss:0.09218084067106247
# loss:0.09233840554952621
# loss:0.09376122057437897
# loss:0.09073064476251602
# loss:0.09177008271217346
# loss:0.09411109983921051
# loss:0.09317285567522049
# loss:0.0929563045501709
# loss:0.09112819284200668
# loss:0.09149066358804703
# loss:0.09085419028997421
# loss:0.0922584980726242
# loss:0.09140561521053314
# loss:0.0923730656504631
# loss:0.09312473237514496
# loss:0.08995530009269714
# loss:0.09323173016309738
# loss:0.08895540237426758
# loss:0.09278462082147598
# loss:0.09096428751945496
# loss:0.0901368111371994
# loss:0.08890698850154877
# loss:0.09234501421451569
# loss:0.09226623177528381
# loss:0.08991586416959763
# loss:0.09050744026899338
# loss:0.0885041132569313
# loss:0.09001567214727402
# loss:0.09018529951572418
# loss:0.09339910000562668
# loss:0.08936091512441635
# loss:0.08970886468887329
# loss:0.09088906645774841
# loss:0.08793053776025772
# loss:0.08958254754543304
# loss:0.09124711900949478
# loss:0.08647196739912033
# loss:0.09176898747682571
# loss:0.0870414674282074
# loss:0.09044729918241501
# loss:0.09003479033708572
# loss:0.09068543463945389
# loss:0.08946291357278824
# loss:0.08725850284099579
# loss:0.08860357105731964
# loss:0.08919116854667664
# loss:0.08904392272233963
# loss:0.08660946041345596
# loss:0.0880473330616951
# loss:0.08949913084506989
# loss:0.09050232917070389
# loss:0.08897367119789124
# loss:0.08884279429912567
# loss:0.08599427342414856
# loss:0.08587046712636948
# loss:0.08704614639282227
# loss:0.09108158946037292
# loss:0.08776814490556717
# loss:0.08804842829704285
# loss:0.08555388450622559
# loss:0.08969386667013168
# loss:0.08741440623998642
# loss:0.08943913131952286
# loss:0.08717644214630127
# loss:0.08893539756536484
# loss:0.08759436011314392
# loss:0.08644048869609833
# loss:0.0886707678437233
# loss:0.08547982573509216
# loss:0.08460336178541183
# loss:0.08769603818655014
# loss:0.08928634226322174
# loss:0.08604782819747925
# loss:0.08773408830165863
# loss:0.08901810646057129
# loss:0.08798271417617798
# loss:0.08862229436635971
# loss:0.08694035559892654
# loss:0.08849712461233139
# loss:0.08541467040777206
# loss:0.08849328756332397
# loss:0.08714935183525085
# loss:0.08920274674892426
# loss:0.08798329532146454
# loss:0.08616028726100922
# loss:0.08431372046470642
# loss:0.08731295168399811
# loss:0.08763711899518967
# loss:0.08815713226795197
# loss:0.0861908346414566
# loss:0.08712504059076309
# loss:0.08433055132627487
# loss:0.08684025704860687
# loss:0.08674654364585876
# loss:0.08630158007144928
# loss:0.08466377854347229
# loss:0.08829879760742188
# loss:0.08445125818252563
# loss:0.0854187160730362
# loss:0.08673716336488724
# loss:0.0852004811167717
# loss:0.08520347625017166
# loss:0.08652189373970032
# loss:0.08876814693212509
# loss:0.08757080882787704
# loss:0.08713838458061218
# loss:0.08555621653795242
# loss:0.08641015738248825
# loss:0.08636071532964706
# loss:0.08313126116991043
# loss:0.08454949408769608
# loss:0.08330824226140976
# loss:0.08532942086458206
# loss:0.08702396601438522
# loss:0.08511701971292496
# loss:0.08691369742155075
# loss:0.08371740579605103
# loss:0.0840817242860794
# loss:0.0849638357758522
# loss:0.08407563716173172
# loss:0.08753612637519836
# loss:0.08496320247650146
# loss:0.08539213240146637
# loss:0.08535128831863403
# loss:0.08435726910829544
# loss:0.08549699932336807
# loss:0.08369933813810349
# loss:0.0839654728770256
# loss:0.08224408328533173
# loss:0.08373838663101196
# loss:0.08285265415906906
# loss:0.08375157415866852
# loss:0.08435932546854019
# loss:0.08294622600078583
# loss:0.08557716757059097
# loss:0.08316422253847122
# loss:0.08415713161230087
# loss:0.08519773185253143
# loss:0.0833171159029007
# loss:0.08410590142011642
# loss:0.08276404440402985
# loss:0.08386440575122833
# loss:0.0831877812743187
# loss:0.08437569439411163
# loss:0.08329476416110992
# loss:0.0841999277472496
# loss:0.08057595789432526
# loss:0.08232857286930084
# loss:0.08445128053426743
# loss:0.08321710675954819
# loss:0.08279851824045181
# loss:0.08431392908096313
# loss:0.08298449218273163
# loss:0.08290549367666245
# loss:0.08342200517654419
# loss:0.08190897852182388
# loss:0.08360805362462997
# loss:0.08381044864654541
# loss:0.08177461475133896
# loss:0.08282231539487839
# loss:0.08288279920816422
# loss:0.08302755653858185
# loss:0.08318177610635757
# loss:0.08251897245645523
# loss:0.08064233511686325
# loss:0.08184128254652023
# loss:0.08269631862640381
# loss:0.08182116597890854
# loss:0.08185061812400818
# loss:0.08086258918046951
# loss:0.08301634341478348
# loss:0.07969160377979279
# loss:0.08270641416311264
# loss:0.08291182667016983
# loss:0.07932400703430176
# loss:0.07906019687652588
# loss:0.08065467327833176
# loss:0.08288607001304626
# loss:0.08296148478984833
# loss:0.0817854031920433
# loss:0.0812498927116394
# loss:0.08301057666540146
# loss:0.08084838092327118
# loss:0.08194354176521301
# loss:0.08105061948299408
# loss:0.08396276086568832
# loss:0.07987713068723679
# loss:0.08134609460830688
# loss:0.08201950043439865
# loss:0.08260674774646759
# loss:0.07985980808734894
# loss:0.08209848403930664
# loss:0.08070012927055359
# loss:0.07981052249670029
# loss:0.08137743175029755
# loss:0.08136574923992157
# loss:0.07883798331022263
# loss:0.08102821558713913
# loss:0.0809304490685463
# loss:0.08104626834392548
# loss:0.07706718146800995
# loss:0.07897907495498657
# loss:0.08024823665618896
# loss:0.08038575202226639
# loss:0.08106580376625061
# loss:0.08028203248977661
# loss:0.08107269555330276
# loss:0.07999175041913986
# loss:0.07888270914554596
# loss:0.08057352155447006
# loss:0.07923336327075958
# loss:0.08166512101888657
# loss:0.08098963648080826
# loss:0.07906220108270645
# loss:0.07890687882900238
# loss:0.08107196539640427
# loss:0.07962994277477264
# loss:0.07968384027481079
# loss:0.07912575453519821
# loss:0.07998307794332504
# loss:0.07963772118091583
# loss:0.08019769191741943
# loss:0.07900889962911606
# loss:0.08055365085601807
# loss:0.07803823798894882
# loss:0.08051610738039017
# loss:0.07775072008371353
# loss:0.07964642345905304
# loss:0.0784657672047615
# loss:0.07931751012802124
# loss:0.07635984569787979
# loss:0.07918239384889603
# loss:0.07914543151855469
# loss:0.07876750826835632
# loss:0.0788104310631752
# loss:0.0796862244606018
# loss:0.08094128221273422
# loss:0.07936105877161026
# loss:0.07900533825159073
# loss:0.07737690210342407
# loss:0.08079130947589874
# loss:0.0775032564997673
# loss:0.08059276640415192
# loss:0.0797133669257164
# loss:0.07660441100597382
# loss:0.07805439084768295
# loss:0.07812996208667755
# loss:0.08131933957338333
# loss:0.07797673344612122
# loss:0.0781947523355484
# loss:0.07891903817653656
# loss:0.07803013920783997
# loss:0.08073393255472183
# loss:0.07592696696519852
# loss:0.07698938250541687
# loss:0.07823924720287323
# loss:0.07660313695669174
# loss:0.07747078686952591
# loss:0.08065558224916458
# loss:0.07759065181016922
# loss:0.07985392212867737
# loss:0.07695730775594711
# loss:0.07831498235464096
# loss:0.07794392108917236
# loss:0.07536445558071136
# loss:0.08109860867261887
# loss:0.07836217433214188
# loss:0.07545787841081619
# loss:0.07913396507501602
# loss:0.0782192200422287
# loss:0.07608116418123245
# loss:0.07920979708433151
# loss:0.07625745236873627
# loss:0.07777240872383118
# loss:0.07947506755590439
# loss:0.07874938100576401
# loss:0.07987653464078903
# loss:0.07853758335113525
# loss:0.07945266366004944
# loss:0.07553385943174362
# loss:0.07697854191064835
# loss:0.07483172416687012
# loss:0.07588561624288559
# loss:0.07753939181566238
# loss:0.07639826089143753
# loss:0.07852675765752792
# loss:0.07588230818510056
# loss:0.07616133242845535
# loss:0.07682052999734879
# loss:0.07552485167980194
# loss:0.0774359479546547
# loss:0.07712281495332718
# loss:0.07790381461381912
# loss:0.07864603400230408
# loss:0.07593434303998947
# loss:0.07738444209098816
# loss:0.07691386342048645
# loss:0.07728000730276108
# loss:0.07469736784696579
# loss:0.07832624763250351
# loss:0.07546208053827286
# loss:0.079612597823143
# loss:0.07731955498456955
# loss:0.07613949477672577
# loss:0.07669595628976822
# loss:0.07665497064590454
# loss:0.07610560208559036
# loss:0.07611879706382751
# loss:0.07316479086875916
# loss:0.07526189833879471
# loss:0.07531483471393585
# loss:0.07497920095920563
# loss:0.07444366812705994
# loss:0.07546199858188629
# loss:0.0750158429145813
# loss:0.07588744163513184
# loss:0.07610061019659042
# loss:0.07759665697813034
# loss:0.07695221900939941
# loss:0.07373778522014618
# loss:0.07601596415042877
# loss:0.07455247640609741
# loss:0.0751018077135086
# loss:0.07896392792463303
# loss:0.07709060609340668
# loss:0.07538311928510666
# loss:0.07702460885047913
# loss:0.07597321271896362
# loss:0.0769878402352333
# loss:0.07824957370758057
# loss:0.07684582471847534
# loss:0.07587342709302902
# loss:0.07727765291929245
# loss:0.07470587641000748
# loss:0.07588278502225876
# loss:0.07466767728328705
# loss:0.07653070986270905
# loss:0.07705916464328766
# loss:0.07492263615131378
# loss:0.07610172033309937
# loss:0.07345294952392578
# loss:0.07486986368894577
# loss:0.07613840699195862
# loss:0.07459595054388046
# loss:0.0743112713098526
# loss:0.07612819969654083
# loss:0.07846710830926895
# loss:0.07653578370809555
# loss:0.07530402392148972
# loss:0.07567621767520905
# loss:0.07424423098564148
# loss:0.07546067982912064
# loss:0.07883206009864807
# loss:0.07496092468500137
# loss:0.07567241042852402
# loss:0.07461421936750412
# loss:0.07402985543012619
# loss:0.07509102672338486
# loss:0.07511477917432785
# loss:0.0754459872841835
# loss:0.07542234659194946
# loss:0.0759328156709671
# loss:0.07497693598270416
# loss:0.07514394074678421
# loss:0.07378699630498886
# loss:0.07505691051483154
# loss:0.0732598602771759
# loss:0.07368309795856476
# loss:0.0740431398153305
# loss:0.07471555471420288
# loss:0.07493524253368378
# loss:0.07469060271978378
# loss:0.07469138503074646
# loss:0.07459902763366699
# loss:0.07296601682901382
# loss:0.07713253796100616
# loss:0.07590461522340775
# loss:0.07247089594602585
# loss:0.07684111595153809
# loss:0.07439412921667099
# loss:0.07488921284675598
# loss:0.07311759144067764
# loss:0.07410913705825806
# loss:0.07256462424993515
# loss:0.07503412663936615
# loss:0.0749204084277153
# loss:0.07576124370098114
# loss:0.0781027153134346
# loss:0.07360614091157913
# loss:0.0751665011048317
# loss:0.07364534586668015
# loss:0.07270318269729614
# loss:0.07156617939472198
# loss:0.07516955584287643
# loss:0.07472210377454758
# loss:0.07360206544399261
# loss:0.07313857227563858
# loss:0.07458648085594177
# loss:0.07725927233695984
# loss:0.07418077439069748
# loss:0.07342544943094254
# loss:0.07436316460371017
# loss:0.07351283729076385
# loss:0.07622750103473663
# loss:0.07363216578960419
# loss:0.07265081256628036
# loss:0.07515473663806915
# loss:0.07348494231700897
# loss:0.07176755368709564
# loss:0.07448077946901321
# loss:0.07428069412708282
# loss:0.07542253285646439
# loss:0.0750003308057785
# loss:0.0748758465051651
# loss:0.07275430113077164
# loss:0.07553020119667053
# loss:0.07519479840993881
# loss:0.07267437875270844
# loss:0.073112353682518
# loss:0.07304484397172928
# loss:0.0772700160741806
# loss:0.07250066101551056
# loss:0.07386811077594757
# loss:0.07335209846496582
# loss:0.0715574324131012
# loss:0.07346928119659424
# loss:0.07278084754943848
# loss:0.07275441288948059
# loss:0.07251428812742233
# loss:0.07390148937702179
# loss:0.07429111748933792
# loss:0.07321716845035553
# loss:0.07157272845506668
# loss:0.07165464758872986
# loss:0.07339970767498016
# loss:0.07311805337667465
# loss:0.07079958915710449
# loss:0.07370422780513763
# loss:0.07405892014503479
# loss:0.07137542963027954
# loss:0.07118150591850281
# loss:0.07455286383628845
# loss:0.07314024120569229
# loss:0.07244250178337097
# loss:0.07077134400606155
# loss:0.07247880846261978
# loss:0.07140102982521057
# loss:0.07460396736860275
# loss:0.07313621044158936
# loss:0.07193859666585922
# loss:0.07281046360731125
# loss:0.0706530511379242
# loss:0.07076064497232437
# loss:0.0727817565202713
# loss:0.07305124402046204
# loss:0.07215643674135208
# loss:0.07261243462562561
# loss:0.07226666063070297
# loss:0.0720859095454216
# loss:0.07147829234600067
# loss:0.07181937247514725
# loss:0.0712430402636528
# loss:0.07241027802228928
# loss:0.07033270597457886
# loss:0.07293163985013962
# loss:0.07149411737918854
# loss:0.07154477387666702
# loss:0.07252957671880722
# loss:0.07183288037776947
# loss:0.07173345983028412
# loss:0.0713946595788002
# loss:0.07242994010448456
# loss:0.071116603910923
# loss:0.07379940897226334
# loss:0.07100951671600342
# loss:0.07418949156999588
# loss:0.0730297863483429
# loss:0.07026423513889313
# loss:0.07297340780496597
# loss:0.07185396552085876
# loss:0.0689559280872345

# %%
trained_param = state.params

# %%
qs = np.random.uniform(panda_model.lb[:7], panda_model.ub[:7], size=(10000,7))
x_succ, x_fail = get_batch_samples(qs)
failed = nn.sigmoid(model.apply(trained_param, x_succ)) < 0.5

# %%
grad_fn = jax.jacrev(model.apply, argnums=1)

# %%
x = x_fail[2]

# %%
x_grad = grad_fn(trained_param, x)[0]
x = x + x_grad*0.001
print(model.apply(trained_param, x))

frame.set_pose(SE3(x[:7]).normalize())
sphere.set_translate(x[7:])
print(x[7:])
# Out:
# [21.614344]
# [-0.21727435 -0.09344015 -0.03501084]

# %%
panda.set_joint_angles(jnp.zeros(9))

# %%
frame = Frame(world.vis, "debug", length=0.15)
sphere1 = Sphere(world.vis, "shoulder", 0.1, "red", 0.5)
sphere2 = Sphere(world.vis, "elbow", 0.1, "red", 0.5)
#box = Sphere(world.vis, "elbow", 0.1, "red", 0.5)
sphere3 = Sphere(world.vis, "wrist", 0.1, "red", 0.5)

# %%
#panda.set_joint_angles(panda_model.neutral)
panda.set_joint_angles(qrand)

# %%
fks = panda_model.fk_fn(panda_model.neutral)
ee_pose = SE3(fks[-1])
shoulder = fks[2][-3:]
elbow = fks[4][-3:]
wrist = fks[7][-3:]
upper_arm_length = jnp.linalg.norm(elbow - shoulder)
wrist_wrt_ee = ee_pose.inverse().apply(wrist)

# %%
qrand = np.random.uniform(panda_model.lb, panda_model.ub)
fks = panda_model.fk_fn(qrand)
ee_pose = SE3(fks[-1])

# %%
def get_sample(q, xyz, noise):
    fks = panda_model.fk_fn(q)
    wrist = fks[7][-3:]
    elbow = fks[4][-3:]
    x_succ = jnp.hstack([wrist, elbow])
    x_fail1 = jnp.hstack([wrist, xyz])
    x_fail2 = jnp.hstack([wrist, elbow+noise])
    x_fail = jnp.vstack([x_fail1, x_fail2])
    return x_succ, x_fail
get_sample_batch = jax.jit(jax.vmap(get_sample, in_axes=(0,0,0)))

# qs = np.random.uniform(panda_model.lb, panda_model.ub, size=(100,9))
# xyz_random = np.random.uniform([-1,-1, -0.5], [1, 1, 1.5], size=(100,3))
# x_succ, x_fail = get_sample_batch(qs, xyz_random)

# %%
#train
def loss(state, params, x_succ, x_fail):
    logits_succ = state.apply_fn(params, x_succ).flatten()
    loss_succ = optax.sigmoid_binary_cross_entropy(
        logits_succ, jnp.ones_like(logits_succ)).mean()
    logits_fail = state.apply_fn(params, x_fail).flatten()
    loss_fail = optax.sigmoid_binary_cross_entropy(
        logits_fail, jnp.zeros_like(logits_fail)).mean()
    return loss_succ + loss_fail
grad_fn = jax.value_and_grad(loss, argnums=1)
@jax.jit
def training_step(state, x_succ, x_fail):
    loss, grads = grad_fn(state, state.params, x_succ, x_fail)
    state = state.apply_gradients(grads=grads)
    return state, loss

# %%
# init train
from jax import random
hp = Hyperparam()
hp.dims = [6, 32, 32, 1]
hp.lr = 0.001
hp.batch_size = 128

model = get_mlp(hp)
key1, key2 = random.split(random.PRNGKey(0))
x = random.normal(key1, (hp.dims[0],))
params = model.init(key2, x)
tx = optax.adam(learning_rate=hp.lr)
state = TrainState.create(apply_fn=model.apply, params=params, tx=tx)

# %%
# training loop
num_batch = 100
for epoch in range(1000):
    qs = np.random.uniform(panda_model.lb, panda_model.ub, size=(num_batch,9))
    xyz_random = np.random.uniform([-1,-1, -0.5], [1, 1, 1.5], size=(num_batch,3))
    noise = np.random.normal(size=(num_batch,3)) * 0.5
    x_succ, x_fail = get_sample_batch(qs, xyz_random, noise)
    state, loss = training_step(state, x_succ, x_fail)
    print(f"loss:{loss}")
# Out:
# loss:0.06978580355644226
# loss:0.06231020390987396
# loss:0.03874324634671211
# loss:0.03303641453385353
# loss:0.05097556486725807
# loss:0.025167366489768028
# loss:0.02388017624616623
# loss:0.07452349364757538
# loss:0.09798727184534073
# loss:0.028322262689471245
# loss:0.05155383422970772
# loss:0.02694651298224926
# loss:0.0403045117855072
# loss:0.01377770584076643
# loss:0.05661853775382042
# loss:0.012205051258206367
# loss:0.039094626903533936
# loss:0.07685178518295288
# loss:0.007445528171956539
# loss:0.07751922309398651
# loss:0.09573078155517578
# loss:0.031236805021762848
# loss:0.04464467614889145
# loss:0.06775760650634766
# loss:0.042640700936317444
# loss:0.011574069038033485
# loss:0.042792461812496185
# loss:0.033325694501399994
# loss:0.050440479069948196
# loss:0.045409440994262695
# loss:0.09014075249433517
# loss:0.05087340250611305
# loss:0.05347944423556328
# loss:0.04404553025960922
# loss:0.09530609101057053
# loss:0.08137667179107666
# loss:0.07459788024425507
# loss:0.04642801359295845
# loss:0.037995509803295135
# loss:0.03250178322196007
# loss:0.013752204366028309
# loss:0.04002639278769493
# loss:0.05303575471043587
# loss:0.05420641228556633
# loss:0.059360671788454056
# loss:0.0367310494184494
# loss:0.06551457196474075
# loss:0.01243185717612505
# loss:0.04598028212785721
# loss:0.035848844796419144
# loss:0.046435438096523285
# loss:0.010977487079799175
# loss:0.06833338737487793
# loss:0.05439155921339989
# loss:0.06071005016565323
# loss:0.01084560714662075
# loss:0.06475350260734558
# loss:0.15182170271873474
# loss:0.013928502798080444
# loss:0.01787193864583969
# loss:0.09458409249782562
# loss:0.0446237176656723
# loss:0.03380482643842697
# loss:0.05041448026895523
# loss:0.041287925094366074
# loss:0.042076125741004944
# loss:0.027637088671326637
# loss:0.012665471993386745
# loss:0.047005776315927505
# loss:0.013605623506009579
# loss:0.07866209745407104
# loss:0.02804957889020443
# loss:0.03430239111185074
# loss:0.05719517171382904
# loss:0.04231637716293335
# loss:0.018797501921653748
# loss:0.03684300556778908
# loss:0.07818666845560074
# loss:0.019164176657795906
# loss:0.050935644656419754
# loss:0.04743136465549469
# loss:0.025578564032912254
# loss:0.017707034945487976
# loss:0.05452150106430054
# loss:0.0124351279810071
# loss:0.07565487176179886
# loss:0.1827133595943451
# loss:0.03864870220422745
# loss:0.03425735607743263
# loss:0.07074595242738724
# loss:0.0546104721724987
# loss:0.08947382867336273
# loss:0.03593199700117111
# loss:0.018453845754265785
# loss:0.035823170095682144
# loss:0.04258653149008751
# loss:0.03434254974126816
# loss:0.0772743746638298
# loss:0.035828642547130585
# loss:0.0491228811442852
# loss:0.043708331882953644
# loss:0.09395572543144226
# loss:0.06495668739080429
# loss:0.019466063007712364
# loss:0.025422267615795135
# loss:0.04101324453949928
# loss:0.03467050939798355
# loss:0.04085300862789154
# loss:0.09741037338972092
# loss:0.03579137846827507
# loss:0.015912218019366264
# loss:0.0505690760910511
# loss:0.02538759633898735
# loss:0.016394183039665222
# loss:0.0506012924015522
# loss:0.058450426906347275
# loss:0.038840845227241516
# loss:0.03256930410861969
# loss:0.04061377793550491
# loss:0.032472822815179825
# loss:0.037277255207300186
# loss:0.08731969445943832
# loss:0.03252250701189041
# loss:0.05232350155711174
# loss:0.058125607669353485
# loss:0.09922317415475845
# loss:0.045403044670820236
# loss:0.03177069500088692
# loss:0.05395268276333809
# loss:0.05640794709324837
# loss:0.05069675296545029
# loss:0.0394599549472332
# loss:0.03798104077577591
# loss:0.07774410396814346
# loss:0.02896793745458126
# loss:0.011976209469139576
# loss:0.06772610545158386
# loss:0.057402703911066055
# loss:0.055382147431373596
# loss:0.021116318181157112
# loss:0.050001051276922226
# loss:0.019058743491768837
# loss:0.11341174691915512
# loss:0.05857659503817558
# loss:0.06927035748958588
# loss:0.0451045036315918
# loss:0.06844339519739151
# loss:0.011226467788219452
# loss:0.03341304883360863
# loss:0.024825185537338257
# loss:0.04348369687795639
# loss:0.08294159173965454
# loss:0.02633201703429222
# loss:0.012706737034022808
# loss:0.0596206896007061
# loss:0.07491429895162582
# loss:0.055987197905778885
# loss:0.052785102277994156
# loss:0.040623988956213
# loss:0.012252157554030418
# loss:0.07096628844738007
# loss:0.01422576792538166
# loss:0.026500308886170387
# loss:0.04019246995449066
# loss:0.033064816147089005
# loss:0.06679912656545639
# loss:0.01860252395272255
# loss:0.018102480098605156
# loss:0.018885454162955284
# loss:0.007590611465275288
# loss:0.030035898089408875
# loss:0.01689901389181614
# loss:0.049336086958646774
# loss:0.06083068624138832
# loss:0.028531987220048904
# loss:0.06772249191999435
# loss:0.01986042782664299
# loss:0.06582299619913101
# loss:0.009453904815018177
# loss:0.03515113145112991
# loss:0.034360773861408234
# loss:0.03655659407377243
# loss:0.04959091916680336
# loss:0.06643626093864441
# loss:0.059753723442554474
# loss:0.019267437979578972
# loss:0.06792927533388138
# loss:0.03207147493958473
# loss:0.02300584875047207
# loss:0.04332285374403
# loss:0.023347903043031693
# loss:0.042139142751693726
# loss:0.07913337647914886
# loss:0.01051938533782959
# loss:0.0216754712164402
# loss:0.0759090706706047
# loss:0.04258416220545769
# loss:0.06387920677661896
# loss:0.031408559530973434
# loss:0.04480951279401779
# loss:0.02886091358959675
# loss:0.016308646649122238
# loss:0.033414602279663086
# loss:0.08756664395332336
# loss:0.027959395200014114
# loss:0.07045237720012665
# loss:0.01731340028345585
# loss:0.017791416496038437
# loss:0.03183460980653763
# loss:0.04635981470346451
# loss:0.02968980371952057
# loss:0.060455624014139175
# loss:0.029631800949573517
# loss:0.031629178673028946
# loss:0.07160976529121399
# loss:0.05387429893016815
# loss:0.04067488759756088
# loss:0.08813237398862839
# loss:0.033490944653749466
# loss:0.008733564056456089
# loss:0.045392509549856186
# loss:0.05111147090792656
# loss:0.03155539929866791
# loss:0.043137822300195694
# loss:0.09583951532840729
# loss:0.04797937348484993
# loss:0.13468575477600098
# loss:0.024220334365963936
# loss:0.07774441689252853
# loss:0.029503921046853065
# loss:0.02510729432106018
# loss:0.05199577659368515
# loss:0.09472259879112244
# loss:0.039143092930316925
# loss:0.03910345211625099
# loss:0.044060010462999344
# loss:0.07619720697402954
# loss:0.041321445256471634
# loss:0.06505344063043594
# loss:0.021732574328780174
# loss:0.06474567949771881
# loss:0.03018457442522049
# loss:0.0442952997982502
# loss:0.032388120889663696
# loss:0.049446772783994675
# loss:0.03945130854845047
# loss:0.08037155866622925
# loss:0.05048547685146332
# loss:0.04519013687968254
# loss:0.056960638612508774
# loss:0.014669438824057579
# loss:0.025745052844285965
# loss:0.05788791552186012
# loss:0.026964319869875908
# loss:0.06176061928272247
# loss:0.033715929836034775
# loss:0.07773926109075546
# loss:0.026925738900899887
# loss:0.06510456651449203
# loss:0.04534098505973816
# loss:0.053838182240724564
# loss:0.019624797627329826
# loss:0.019146300852298737
# loss:0.0412546843290329
# loss:0.025460734963417053
# loss:0.013422584161162376
# loss:0.06634476035833359
# loss:0.018664833158254623
# loss:0.017945416271686554
# loss:0.039549876004457474
# loss:0.06249081715941429
# loss:0.06190690025687218
# loss:0.005875841714441776
# loss:0.045711539685726166
# loss:0.05690697953104973
# loss:0.030133945867419243
# loss:0.029970163479447365
# loss:0.03246784582734108
# loss:0.009134250693023205
# loss:0.07791251689195633
# loss:0.08876144140958786
# loss:0.030545363202691078
# loss:0.039859589189291
# loss:0.03537832573056221
# loss:0.01351192221045494
# loss:0.055452749133110046
# loss:0.042716968804597855
# loss:0.06661203503608704
# loss:0.026202227920293808
# loss:0.008421359583735466
# loss:0.01984056830406189
# loss:0.1200217604637146
# loss:0.11859364062547684
# loss:0.051286738365888596
# loss:0.09076989442110062
# loss:0.06275731325149536
# loss:0.0481623075902462
# loss:0.05270569398999214
# loss:0.06619687378406525
# loss:0.024765800684690475
# loss:0.015582406893372536
# loss:0.08400751650333405
# loss:0.018421132117509842
# loss:0.032241106033325195
# loss:0.02262057177722454
# loss:0.0734824538230896
# loss:0.040454715490341187
# loss:0.023267028853297234
# loss:0.03697284311056137
# loss:0.048973072320222855
# loss:0.021197278052568436
# loss:0.06357332319021225
# loss:0.024312134832143784
# loss:0.04643385857343674
# loss:0.07467521727085114
# loss:0.009630156680941582
# loss:0.04126347228884697
# loss:0.010850495658814907
# loss:0.014365420676767826
# loss:0.023427918553352356
# loss:0.05990367382764816
# loss:0.021596737205982208
# loss:0.07909658551216125
# loss:0.04821440577507019
# loss:0.049553029239177704
# loss:0.015680020675063133
# loss:0.03933996707201004
# loss:0.06986182183027267
# loss:0.10921547561883926
# loss:0.052901312708854675
# loss:0.022810358554124832
# loss:0.014195548370480537
# loss:0.021679257974028587
# loss:0.041154664009809494
# loss:0.0156600009649992
# loss:0.0410422645509243
# loss:0.016974667087197304
# loss:0.08336907625198364
# loss:0.02844010293483734
# loss:0.058665674179792404
# loss:0.01776304841041565
# loss:0.008820049464702606
# loss:0.017431318759918213
# loss:0.04505133628845215
# loss:0.04816480726003647
# loss:0.06754984706640244
# loss:0.09463437646627426
# loss:0.04938272014260292
# loss:0.082316555082798
# loss:0.021505707874894142
# loss:0.028847185894846916
# loss:0.01682194508612156
# loss:0.025959467515349388
# loss:0.023721328005194664
# loss:0.07234372943639755
# loss:0.03931387513875961
# loss:0.09440230578184128
# loss:0.05841644108295441
# loss:0.020274853333830833
# loss:0.04059091955423355
# loss:0.026758817955851555
# loss:0.07762287557125092
# loss:0.013997607864439487
# loss:0.06469609588384628
# loss:0.01602734811604023
# loss:0.023692967370152473
# loss:0.0680648684501648
# loss:0.032209623605012894
# loss:0.018604256212711334
# loss:0.014935307204723358
# loss:0.04552857205271721
# loss:0.05510982125997543
# loss:0.03854953870177269
# loss:0.08659818768501282
# loss:0.07213229686021805
# loss:0.0331711545586586
# loss:0.05323394387960434
# loss:0.03922000527381897
# loss:0.046581853181123734
# loss:0.0092947818338871
# loss:0.09735003858804703
# loss:0.02230958640575409
# loss:0.037945449352264404
# loss:0.013031278736889362
# loss:0.013177196495234966
# loss:0.016824811697006226
# loss:0.035246286541223526
# loss:0.03405148535966873
# loss:0.03949575871229172
# loss:0.008801443502306938
# loss:0.07297426462173462
# loss:0.047912467271089554
# loss:0.07305440306663513
# loss:0.02201477624475956
# loss:0.05740844085812569
# loss:0.013703403063118458
# loss:0.027458010241389275
# loss:0.04586069658398628
# loss:0.022945675998926163
# loss:0.028226610273122787
# loss:0.019639885053038597
# loss:0.01905941776931286
# loss:0.05755011737346649
# loss:0.05518018826842308
# loss:0.03524976596236229
# loss:0.03077567182481289
# loss:0.06170288473367691
# loss:0.04129840061068535
# loss:0.02766197733581066
# loss:0.02328580990433693
# loss:0.06499379128217697
# loss:0.08398889005184174
# loss:0.05110213905572891
# loss:0.05876586586236954
# loss:0.027378074824810028
# loss:0.027143562212586403
# loss:0.02969437465071678
# loss:0.053395066410303116
# loss:0.011659466661512852
# loss:0.06521983444690704
# loss:0.05432102084159851
# loss:0.02213047631084919
# loss:0.06009317934513092
# loss:0.02505454607307911
# loss:0.012647189199924469
# loss:0.04768675938248634
# loss:0.022456394508481026
# loss:0.08270775526762009
# loss:0.027529718354344368
# loss:0.05338172987103462
# loss:0.030806828290224075
# loss:0.03560006991028786
# loss:0.013604589737951756
# loss:0.018275082111358643
# loss:0.015928899869322777
# loss:0.02402166649699211
# loss:0.013236721977591515
# loss:0.055474475026130676
# loss:0.07077732682228088
# loss:0.037236832082271576
# loss:0.09124218672513962
# loss:0.055857282131910324
# loss:0.07001164555549622
# loss:0.029930079355835915
# loss:0.007718904875218868
# loss:0.058177582919597626
# loss:0.020890023559331894
# loss:0.01644054427742958
# loss:0.0301367100328207
# loss:0.11246967315673828
# loss:0.01634877547621727
# loss:0.02410798706114292
# loss:0.05257616937160492
# loss:0.05155424773693085
# loss:0.014512082561850548
# loss:0.05955374613404274
# loss:0.031441763043403625
# loss:0.04233527183532715
# loss:0.039702896028757095
# loss:0.06215830147266388
# loss:0.07473304867744446
# loss:0.0663333535194397
# loss:0.03850119188427925
# loss:0.01892000436782837
# loss:0.06199612468481064
# loss:0.019248545169830322
# loss:0.05525616928935051
# loss:0.03928134962916374
# loss:0.0151866739615798
# loss:0.020909830927848816
# loss:0.08123897761106491
# loss:0.06053409352898598
# loss:0.03874102979898453
# loss:0.06316213309764862
# loss:0.017459791153669357
# loss:0.03873500972986221
# loss:0.03258160129189491
# loss:0.015271044336259365
# loss:0.014050585217773914
# loss:0.057443179190158844
# loss:0.03209182620048523
# loss:0.029093142598867416
# loss:0.08499333262443542
# loss:0.02081528678536415
# loss:0.02040964551270008
# loss:0.038953833281993866
# loss:0.103874072432518
# loss:0.024635497480630875
# loss:0.07187754660844803
# loss:0.012479875236749649
# loss:0.0399702750146389
# loss:0.020169666036963463
# loss:0.08276532590389252
# loss:0.029786864295601845
# loss:0.03357795998454094
# loss:0.04189475625753403
# loss:0.03844594210386276
# loss:0.02705444023013115
# loss:0.10472450405359268
# loss:0.025815652683377266
# loss:0.05688098073005676
# loss:0.020351016893982887
# loss:0.01592548005282879
# loss:0.036020711064338684
# loss:0.05021784082055092
# loss:0.13063658773899078
# loss:0.012784191407263279
# loss:0.03754947707056999
# loss:0.019204549491405487
# loss:0.03862185403704643
# loss:0.01065860502421856
# loss:0.04823426902294159
# loss:0.0331074558198452
# loss:0.08632316440343857
# loss:0.06188542768359184
# loss:0.06920629739761353
# loss:0.049705442041158676
# loss:0.019210297614336014
# loss:0.019414305686950684
# loss:0.07130187004804611
# loss:0.020298229530453682
# loss:0.07529818266630173
# loss:0.07445164024829865
# loss:0.008171620778739452
# loss:0.052204616367816925
# loss:0.01618024706840515
# loss:0.04478045925498009
# loss:0.027393512427806854
# loss:0.022305402904748917
# loss:0.06778120249509811
# loss:0.04733642190694809
# loss:0.02616078406572342
# loss:0.01246759295463562
# loss:0.061276838183403015
# loss:0.057700265198946
# loss:0.04807037115097046
# loss:0.020342815667390823
# loss:0.016349393874406815
# loss:0.010142716579139233
# loss:0.06404248625040054
# loss:0.010068587958812714
# loss:0.046006157994270325
# loss:0.043672192841768265
# loss:0.07457951456308365
# loss:0.05126994475722313
# loss:0.0508597232401371
# loss:0.01915055885910988
# loss:0.00894970539957285
# loss:0.028914405032992363
# loss:0.05519084259867668
# loss:0.024678299203515053
# loss:0.05426175519824028
# loss:0.028569435700774193
# loss:0.029734469950199127
# loss:0.00826203916221857
# loss:0.022683478891849518
# loss:0.061509307473897934
# loss:0.014895517379045486
# loss:0.03598641976714134
# loss:0.01363728940486908
# loss:0.04331396147608757
# loss:0.07736719399690628
# loss:0.02134574204683304
# loss:0.007204601541161537
# loss:0.029227515682578087
# loss:0.08020642399787903
# loss:0.008497025817632675
# loss:0.09182799607515335
# loss:0.03620783984661102
# loss:0.052835822105407715
# loss:0.03861673176288605
# loss:0.017674943432211876
# loss:0.045245904475450516
# loss:0.09827999770641327
# loss:0.019395004957914352
# loss:0.042967263609170914
# loss:0.010361104272305965
# loss:0.0692969337105751
# loss:0.05244417116045952
# loss:0.031885307282209396
# loss:0.07609094679355621
# loss:0.01761176437139511
# loss:0.05873539298772812
# loss:0.0375061109662056
# loss:0.08710715174674988
# loss:0.02590813860297203
# loss:0.050443071871995926
# loss:0.03713473677635193
# loss:0.02882673777639866
# loss:0.06317832320928574
# loss:0.0195428729057312
# loss:0.05984339118003845
# loss:0.04607605189085007
# loss:0.020588601008057594
# loss:0.04720189422369003
# loss:0.0682397186756134
# loss:0.0381506085395813
# loss:0.03723539039492607
# loss:0.029867220669984818
# loss:0.03343084827065468
# loss:0.023028338328003883
# loss:0.00983584113419056
# loss:0.0562148354947567
# loss:0.037913728505373
# loss:0.026095638051629066
# loss:0.03743639215826988
# loss:0.03987801820039749
# loss:0.09578461945056915
# loss:0.033483538776636124
# loss:0.06256739050149918
# loss:0.021762453019618988
# loss:0.030498115345835686
# loss:0.009110651910305023
# loss:0.051690857857465744
# loss:0.035641755908727646
# loss:0.018685374408960342
# loss:0.028204092755913734
# loss:0.04562153294682503
# loss:0.049666184931993484
# loss:0.0886332169175148
# loss:0.04241926968097687
# loss:0.06950940936803818
# loss:0.03722895309329033
# loss:0.053790148347616196
# loss:0.0568859726190567
# loss:0.1012035682797432
# loss:0.09201755374670029
# loss:0.027679014950990677
# loss:0.0168397668749094
# loss:0.05283341556787491
# loss:0.03634496033191681
# loss:0.02206440642476082
# loss:0.01357502955943346
# loss:0.03040166385471821
# loss:0.027170522138476372
# loss:0.02158195525407791
# loss:0.012387506663799286
# loss:0.03674613684415817
# loss:0.0291785579174757
# loss:0.035871949046850204
# loss:0.02662103809416294
# loss:0.030893707647919655
# loss:0.05263257399201393
# loss:0.0815952941775322
# loss:0.02170802839100361
# loss:0.021313326433300972
# loss:0.022598283365368843
# loss:0.04608360305428505
# loss:0.014694854617118835
# loss:0.042456284165382385
# loss:0.059288326650857925
# loss:0.01314822118729353
# loss:0.011820686981081963
# loss:0.11567201465368271
# loss:0.03836957737803459
# loss:0.028869252651929855
# loss:0.033715054392814636
# loss:0.044739559292793274
# loss:0.01688971370458603
# loss:0.079622283577919
# loss:0.032793354243040085
# loss:0.10792116075754166
# loss:0.07715678960084915
# loss:0.09629865735769272
# loss:0.06534799933433533
# loss:0.03652056306600571
# loss:0.05514935031533241
# loss:0.05717548355460167
# loss:0.020816469565033913
# loss:0.04819515720009804
# loss:0.05182488635182381
# loss:0.02560461312532425
# loss:0.04531167075037956
# loss:0.05496954172849655
# loss:0.03340504318475723
# loss:0.06884174048900604
# loss:0.06735145300626755
# loss:0.04628603905439377
# loss:0.039233870804309845
# loss:0.054545219987630844
# loss:0.0797157883644104
# loss:0.043605197221040726
# loss:0.04259767010807991
# loss:0.019336113706231117
# loss:0.05495625361800194
# loss:0.05151581019163132
# loss:0.11721807718276978
# loss:0.03756294399499893
# loss:0.03461868315935135
# loss:0.11960522830486298
# loss:0.01921548694372177
# loss:0.021051641553640366
# loss:0.03451147675514221
# loss:0.026585139334201813
# loss:0.01835106872022152
# loss:0.011420716531574726
# loss:0.0211647916585207
# loss:0.06362925469875336
# loss:0.02818436734378338
# loss:0.026120439171791077
# loss:0.03211724013090134
# loss:0.0073894234374165535
# loss:0.037759266793727875
# loss:0.019014140591025352
# loss:0.015081236138939857
# loss:0.020613735541701317
# loss:0.0680016502737999
# loss:0.0821218192577362
# loss:0.018760964274406433
# loss:0.016767114400863647
# loss:0.10763751715421677
# loss:0.08222441375255585
# loss:0.017978262156248093
# loss:0.030117269605398178
# loss:0.062342219054698944
# loss:0.07266737520694733
# loss:0.03829390928149223
# loss:0.07326871156692505
# loss:0.055643659085035324
# loss:0.040481142699718475
# loss:0.06191939860582352
# loss:0.02493821270763874
# loss:0.023062504827976227
# loss:0.03102792240679264
# loss:0.048794589936733246
# loss:0.04325681924819946
# loss:0.011416807770729065
# loss:0.05941865220665932
# loss:0.013947480358183384
# loss:0.018667053431272507
# loss:0.04481624811887741
# loss:0.011531729251146317
# loss:0.013525272719562054
# loss:0.05110199376940727
# loss:0.0643666684627533
# loss:0.013069089502096176
# loss:0.04264453053474426
# loss:0.008947706781327724
# loss:0.012039780616760254
# loss:0.0640687495470047
# loss:0.036636222153902054
# loss:0.027597784996032715
# loss:0.08800198882818222
# loss:0.056153006851673126
# loss:0.02815932221710682
# loss:0.0637822300195694
# loss:0.057452257722616196
# loss:0.09609641134738922
# loss:0.023865889757871628
# loss:0.029934372752904892
# loss:0.0312686488032341
# loss:0.03415396064519882
# loss:0.019530078396201134
# loss:0.018231768161058426
# loss:0.06896830350160599
# loss:0.060253992676734924
# loss:0.03626339137554169
# loss:0.04299354553222656
# loss:0.04030565172433853
# loss:0.04687284305691719
# loss:0.057279836386442184
# loss:0.07101578265428543
# loss:0.07340490818023682
# loss:0.0630740225315094
# loss:0.023149613291025162
# loss:0.028208309784531593
# loss:0.019886763766407967
# loss:0.01945759542286396
# loss:0.038397032767534256
# loss:0.0173852127045393
# loss:0.030024342238903046
# loss:0.03532598540186882
# loss:0.07446470856666565
# loss:0.010440964251756668
# loss:0.05693468078970909
# loss:0.024169838055968285
# loss:0.03755133971571922
# loss:0.03213568404316902
# loss:0.03419111669063568
# loss:0.04458928480744362
# loss:0.053248971700668335
# loss:0.061566781252622604
# loss:0.014239494688808918
# loss:0.03438718244433403
# loss:0.05008801445364952
# loss:0.023313147947192192
# loss:0.0442337691783905
# loss:0.0789814367890358
# loss:0.008198843337595463
# loss:0.014963097870349884
# loss:0.04218156263232231
# loss:0.06721597909927368
# loss:0.032689329236745834
# loss:0.09336978197097778
# loss:0.0403108075261116
# loss:0.08083022385835648
# loss:0.045580409467220306
# loss:0.027753883972764015
# loss:0.028466694056987762
# loss:0.01731773279607296
# loss:0.03548184409737587
# loss:0.058874595910310745
# loss:0.057923574000597
# loss:0.03277153521776199
# loss:0.042220763862133026
# loss:0.07901493459939957
# loss:0.04047597572207451
# loss:0.0600242093205452
# loss:0.03733760863542557
# loss:0.07447818666696548
# loss:0.04366372898221016
# loss:0.07801695168018341
# loss:0.012516103684902191
# loss:0.030600693076848984
# loss:0.1019214540719986
# loss:0.022426776587963104
# loss:0.053593821823596954
# loss:0.02285180799663067
# loss:0.10214626789093018
# loss:0.03878182917833328
# loss:0.05519072338938713
# loss:0.01796276867389679
# loss:0.05315723642706871
# loss:0.025942591950297356
# loss:0.057518236339092255
# loss:0.0528431311249733
# loss:0.033206891268491745
# loss:0.08288884907960892
# loss:0.011737916618585587
# loss:0.01568451151251793
# loss:0.030783219262957573
# loss:0.0688205137848854
# loss:0.08180280029773712
# loss:0.023154299706220627
# loss:0.006878548301756382
# loss:0.039111796766519547
# loss:0.03588506951928139
# loss:0.13114365935325623
# loss:0.1193266212940216
# loss:0.06076781079173088
# loss:0.12123838812112808
# loss:0.11437921971082687
# loss:0.007918900810182095
# loss:0.07081212103366852
# loss:0.09225330501794815
# loss:0.014221400953829288
# loss:0.029912609606981277
# loss:0.03188315033912659
# loss:0.05662872642278671
# loss:0.07794541120529175
# loss:0.07046659290790558
# loss:0.02133302018046379
# loss:0.024642949923872948
# loss:0.055129218846559525
# loss:0.05545259639620781
# loss:0.012692151591181755
# loss:0.026866737753152847
# loss:0.06146731227636337
# loss:0.08975445479154587
# loss:0.06426696479320526
# loss:0.041105225682258606
# loss:0.03549879044294357
# loss:0.03015114925801754
# loss:0.11929330229759216
# loss:0.013120598159730434
# loss:0.04050460830330849
# loss:0.030858008190989494
# loss:0.033885408192873
# loss:0.05460135266184807
# loss:0.0607331208884716
# loss:0.022954868152737617
# loss:0.028598278760910034
# loss:0.02538747526705265
# loss:0.015983765944838524
# loss:0.045500896871089935
# loss:0.04575169086456299
# loss:0.049483295530080795
# loss:0.015392174012959003
# loss:0.11051668971776962
# loss:0.04077045992016792
# loss:0.014697771519422531
# loss:0.05058645084500313
# loss:0.11288433521986008
# loss:0.049524612724781036
# loss:0.039361290633678436
# loss:0.03380011022090912
# loss:0.06411613523960114
# loss:0.010068646632134914
# loss:0.031962547451257706
# loss:0.03960700333118439
# loss:0.04271809384226799
# loss:0.019767900928854942
# loss:0.036316223442554474
# loss:0.034542106091976166
# loss:0.03494657203555107
# loss:0.012001152150332928
# loss:0.06231319159269333
# loss:0.05189382657408714
# loss:0.03705631569027901
# loss:0.03002040833234787
# loss:0.04860849305987358
# loss:0.02692202478647232
# loss:0.05094848573207855
# loss:0.06500912457704544
# loss:0.03913838043808937
# loss:0.026380572468042374
# loss:0.0613565668463707
# loss:0.013364504091441631
# loss:0.05053400993347168
# loss:0.03487410023808479
# loss:0.048616692423820496
# loss:0.07731561362743378
# loss:0.046719904989004135
# loss:0.06777208298444748
# loss:0.033719729632139206
# loss:0.020830577239394188
# loss:0.03557363525032997
# loss:0.02058178000152111
# loss:0.05525735765695572
# loss:0.08381587266921997
# loss:0.02216833457350731
# loss:0.011715109460055828
# loss:0.04680771380662918
# loss:0.0407390370965004
# loss:0.010175702162086964
# loss:0.016959398984909058
# loss:0.011440197937190533
# loss:0.04004441201686859
# loss:0.008520160801708698
# loss:0.040407150983810425
# loss:0.06844498217105865
# loss:0.07669791579246521
# loss:0.03922296687960625
# loss:0.03524302318692207
# loss:0.014165693894028664
# loss:0.02352837845683098
# loss:0.055373772978782654
# loss:0.012184091843664646
# loss:0.0445597767829895
# loss:0.051387835294008255
# loss:0.0939619243144989
# loss:0.023053716868162155
# loss:0.043616678565740585
# loss:0.0298139825463295
# loss:0.07108709961175919
# loss:0.02068316377699375
# loss:0.028349867090582848
# loss:0.06397319585084915
# loss:0.030058138072490692
# loss:0.039792243391275406
# loss:0.029235221445560455
# loss:0.06109539046883583
# loss:0.032026927918195724
# loss:0.05288717895746231
# loss:0.04573165997862816
# loss:0.04132407158613205
# loss:0.013873843476176262
# loss:0.024514885619282722
# loss:0.02340640500187874
# loss:0.0475086085498333
# loss:0.014158328995108604
# loss:0.014486496336758137
# loss:0.056361082941293716
# loss:0.07020054757595062
# loss:0.040463972836732864
# loss:0.0329982228577137
# loss:0.015929538756608963
# loss:0.06610675901174545
# loss:0.030223481357097626
# loss:0.04319417104125023
# loss:0.060731440782547
# loss:0.013299086131155491
# loss:0.08076778799295425
# loss:0.07899481058120728
# loss:0.02784881368279457
# loss:0.03541332855820656
# loss:0.02637309581041336
# loss:0.05313822627067566
# loss:0.07425949722528458
# loss:0.06243555620312691
# loss:0.03605473041534424
# loss:0.02611549384891987
# loss:0.048104677349328995
# loss:0.058823153376579285
# loss:0.04829501360654831
# loss:0.06310120970010757
# loss:0.12674285471439362
# loss:0.03784174844622612
# loss:0.04474838823080063
# loss:0.0418253168463707
# loss:0.0838523805141449
# loss:0.038646042346954346
# loss:0.028399832546710968
# loss:0.025661960244178772
# loss:0.03747475892305374
# loss:0.04887799918651581
# loss:0.03499075770378113
# loss:0.010806242935359478
# loss:0.024257801473140717
# loss:0.07101647555828094

# %%
trained_params = state.params

# %%
qs = np.random.uniform(panda_model.lb, panda_model.ub, size=(num_batch,9))
xyz_random = np.random.uniform([-1,-1, -0.5], [1, 1, 1.5], size=(num_batch,3))
noise = np.random.normal(size=(num_batch,3))*0.5
x_succ, x_fail = get_sample_batch(qs, xyz_random, noise)

# %%
#make problem
q = panda.get_random_config()
panda.set_joint_angles(q)
ee_pose = SE3(panda_model.fk_fn(panda.q)[-1])
frame.set_pose(ee_pose)

# %%
wrist = ee_pose.apply(wrist_wrt_ee)
sphere2.set_translate(wrist)

# %%
# optimize
@jax.jit
def objective(wrist, elbow):
    upper_arm_err = jnp.abs(safe_2norm(shoulder - elbow) - upper_arm_length)
    lower_arm_len = safe_2norm(elbow - wrist)
    lower_arm_bounded = jnp.clip(lower_arm_len,a_min=0.35, a_max=0.5)
    lower_arm_err = jnp.abs(lower_arm_bounded - lower_arm_len)
    elbow_inf = - model.apply(trained_params, x)[0]
    return upper_arm_err + lower_arm_err + elbow_inf*0.1

# %%
f_vg = jax.value_and_grad(objective, argnums=1)

# %%
save("wrist_elbow_feas", trained_state, hp, force=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[700], line 1
# ----> 1 save("wrist_elbow_feas", trained_state, hp, force=True)
#
# NameError: name 'trained_state' is not defined

# %%
#initialize
# %time
xyz = np.random.uniform([-1,-1,-0.5], [1,1,1.5], size=(100,3))
values = jax.vmap(objective, in_axes=(None,0))(wrist, xyz)
elbow = xyz[values.argmin()]
feasibility = nn.sigmoid(model.apply(trained_params, jnp.hstack([wrist, elbow]))[0])
sphere3.set_translate(elbow)
print(feasibility)
# Out:
# CPU times: user 2 µs, sys: 14 µs, total: 16 µs
# Wall time: 32.9 µs
# 0.053368486

# %%
value, elbow_grad = f_vg(wrist, elbow)

# %%
elbow = elbow - elbow_grad * 0.01
feasibility = nn.sigmoid(model.apply(
    trained_params, jnp.hstack([wrist, elbow]))[0])
sphere3.set_translate(elbow)

print(feasibility)
# Out:
# 0.9956827

# %%
# Out:
# 0.13750944

# %%
elbow_true = panda_model.fk_fn(panda.q)[4][-3:]

# %%
nn.sigmoid(model.apply(trained_params, jnp.hstack([wrist, elbow_true]))[0])
# Out:
# Array(0.99658185, dtype=float32)

# %%
elbow
# Out:
# array([ 0.23603655, -0.24421876,  0.35114774])

# %%
x = jnp.vstack(x_fail)[0]

# %%
x = x_succ[0]

# %%
val_grad_fn = jax.value_and_grad(objective)

# %%
f, x_grad = val_grad_fn(x)
x = x - x_grad * 0.001

#visualize
wrist, elbow = x[:3], x[3:]
sphere2.set_translate(wrist)
sphere3.set_translate(elbow)
print(f"f:{f}")
# Out:
# f:-0.5479756593704224

# %%
#derived:
wrist = ee_pose.apply(wrist_wrt_ee)

# shoulder = fks[2][-3:]
# elbow = fks[4][-3:]
# wrist = fks[7][-3:]


sphere1.set_translate(shoulder)
sphere2.set_translate(wrist)
sphere3.set_translate(elbow)
frame.set_pose(ee_pose)
panda.set_joint_angles(qrand)

lower_arm_length = jnp.linalg.norm(wrist - elbow)
lower_arm_length
# Out:
# Array(0.62608165, dtype=float32)

# %%
# Out:
# Array(0.04690649, dtype=float32)

# %%
qs = jnp.zeros((100,7))
batch_fk(qs).shape
# Out:
# (100, 12, 7)

# %%
frame.set_pose(SE3(panda_model.fk_fn(panda_model.neutral)[-1]))

# %%
elbow_xyz = panda_model.fk_fn(panda_model.neutral)[4][-3:]
ee_pose = SE3(panda_model.fk_fn(panda_model.neutral)[-1])
